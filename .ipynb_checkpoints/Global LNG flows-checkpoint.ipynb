# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\giovanni.sgaravatti\\Bruegel Gitlab\\2021-11-european-natural-gas-imports'

# %%
Share_point = r'C:\Users\giovanni.sgaravatti\Bruegel\Research - 2021-11 European natural gas imports\Code\Imports'

# %%
os.chdir(Share_point)

# %%
import json
import requests
import pandas as pd
import numpy as np

from datetime import datetime
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.dates import DateFormatter
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import seaborn as sns

import eurostat  # python wrapper for taking data.
import time

# %%
# Converter for metric tonnes to M3m 
converter = -0.001397

# %% [markdown]
# ### In Million tonnes

# %%
d1 = pd.read_excel('raw_data/LNG/Global LNG imports 2017-2018.xlsx')
d2 = pd.read_excel('raw_data/LNG/Global LNG imports 2019-2020.xlsx')
d3 = pd.read_excel('raw_data/LNG/Global LNG imports 2021-2022.xlsx')
d4 = pd.read_excel('raw_data/LNG/Global LNG imports 2023.xlsx')

# %%
# Merge 2017 to 2020
df_20 = pd.merge(d1,d2,on=['Origin_Berthcountry','Port_Country'],how='outer')

# %%
# Merge 2017 to 2022
df_22 = pd.merge(df_20,d3,on=['Origin_Berthcountry','Port_Country'],how='outer')

# %%
# Merge 2022 to 2023
df = pd.merge(df_22,d4,on=['Origin_Berthcountry','Port_Country'],how='outer')

# %%
df
# Out:
#                  Port_Country Origin_Berthcountry  2018-12-31 00:00:00  \
# 0                   Argentina             Algeria                  NaN
# 1                   Argentina              Brazil                  NaN
# 2                   Argentina   Equatorial Guinea                  NaN
# 3                   Argentina             Nigeria                  NaN
# 4                   Argentina                Peru                  NaN
# ..                        ...                 ...                  ...
# 614               South Korea          Mozambique                  NaN
# 615                  Thailand          Mozambique                  NaN
# 616                    Turkey          Mozambique                  NaN
# 617                    Turkey              Turkey                  NaN
# 618  United States of America             Jamaica                  NaN
#
#      2018-11-30 00:00:00  2018-10-31 00:00:00  2018-09-30 00:00:00  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 614                  NaN                  NaN                  NaN
# 615                  NaN                  NaN                  NaN
# 616                  NaN                  NaN                  NaN
# 617                  NaN                  NaN                  NaN
# 618                  NaN                  NaN                  NaN
#
#      2018-08-31 00:00:00  2018-07-31 00:00:00  2018-06-30 00:00:00  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN            -63911.70
# 3             -181681.65            -56992.95            -59904.45
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 614                  NaN                  NaN                  NaN
# 615                  NaN                  NaN                  NaN
# 616                  NaN                  NaN                  NaN
# 617                  NaN                  NaN                  NaN
# 618                  NaN                  NaN                  NaN
#
#      2018-05-31 00:00:00  ...  2021-06-30 00:00:00  2021-05-31 00:00:00  \
# 0               -64258.2  ...                  NaN                  NaN
# 1                    NaN  ...                  NaN                  NaN
# 2                    NaN  ...                  NaN                  NaN
# 3               -59980.5  ...                  NaN                  NaN
# 4                    NaN  ...                  NaN                  NaN
# ..                   ...  ...                  ...                  ...
# 614                  NaN  ...                  NaN                  NaN
# 615                  NaN  ...                  NaN                  NaN
# 616                  NaN  ...                  NaN                  NaN
# 617                  NaN  ...                  NaN                  NaN
# 618                  NaN  ...                  NaN                  NaN
#
#      2021-04-30 00:00:00  2021-03-31 00:00:00  2021-02-28 00:00:00  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 614                  NaN                  NaN                  NaN
# 615                  NaN                  NaN                  NaN
# 616                  NaN                  NaN                  NaN
# 617                  NaN                  NaN                  NaN
# 618                  NaN                  NaN                  NaN
#
#      2021-01-31 00:00:00  2023-04-30 00:00:00  2023-03-31 00:00:00  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 614                  NaN                  NaN            -70351.65
# 615                  NaN             -71192.7                  NaN
# 616                  NaN                  NaN                  NaN
# 617                  NaN             -74299.5                  NaN
# 618                  NaN                  NaN                  NaN
#
#      2023-02-28 00:00:00  2023-01-31 00:00:00
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# ..                   ...                  ...
# 614                  NaN                  NaN
# 615                  NaN                  NaN
# 616             -71039.7                  NaN
# 617                  NaN                  NaN
# 618                  NaN             -57206.7
#
# [619 rows x 78 columns]

# %% [markdown]
# ### Single-out China

# %%
china = df[df['Port_Country'].isin(['China'])].reset_index()

# %%
cols = china.iloc[:,1:3]

# %%
cols.tail()
# Out:
#    Port_Country   Origin_Berthcountry
# 24        China               Belgium
# 25        China                 China
# 26        China                 India
# 27        China  United Arab Emirates
# 28        China                 Spain

# %%
# convert to M3m
values = china.iloc[:,3:]*converter

# %%
china = pd.concat([cols,values], axis=1)

# %%
china = china.groupby(['Origin_Berthcountry']).sum(numeric_only=True)

# %%
china = china.T #drop(

# %%
china.index = pd.to_datetime(china.index)
china = china.sort_index()

# %%
china.head()
# Out:
# Origin_Berthcountry    Algeria     Angola    Australia  Belgium  \
# 2017-01-31            0.000000   0.000000  1461.408825      0.0
# 2017-02-28            0.000000   0.000000  1219.785940      0.0
# 2017-03-31            0.000000  91.627623  1488.186800      0.0
# 2017-04-30            0.000000  91.941320  1312.753217      0.0
# 2017-05-31           78.642229  91.082584  2105.710324      0.0
#
# Origin_Berthcountry  Brunei Darussalam  Cameroon  China  Egypt  \
# 2017-01-31                         0.0       0.0    0.0    0.0
# 2017-02-28                         0.0       0.0    0.0    0.0
# 2017-03-31                         0.0       0.0    0.0    0.0
# 2017-04-30                         0.0       0.0    0.0    0.0
# 2017-05-31                         0.0       0.0    0.0    0.0
#
# Origin_Berthcountry  Equatorial Guinea     France  ...  Peru        Qatar  \
# 2017-01-31                    0.000000   0.000000  ...   0.0  1383.529777
# 2017-02-28                   99.157593   0.000000  ...   0.0   733.129115
# 2017-03-31                    0.000000   0.000000  ...   0.0   402.000930
# 2017-04-30                    0.000000   0.000000  ...   0.0   646.263516
# 2017-05-31                    0.000000  87.743824  ...   0.0   632.127063
#
# Origin_Berthcountry     Russia  Singapore  South Korea  Spain  \
# 2017-01-31           87.112031   0.000000          0.0    0.0
# 2017-02-28            0.000000  91.239746          0.0    0.0
# 2017-03-31            0.000000   0.000000          0.0    0.0
# 2017-04-30            0.000000   0.000000          0.0    0.0
# 2017-05-31           86.118135   0.000000          0.0    0.0
#
# Origin_Berthcountry  Trinidad & Tobago  United Arab Emirates  United Kingdom  \
# 2017-01-31                   98.999802                   0.0             0.0
# 2017-02-28                    0.000000                   0.0             0.0
# 2017-03-31                    0.000000                   0.0             0.0
# 2017-04-30                    0.000000                   0.0             0.0
# 2017-05-31                    0.000000                   0.0             0.0
#
# Origin_Berthcountry  United States of America
# 2017-01-31                         179.698974
# 2017-02-28                          98.406985
# 2017-03-31                         197.545090
# 2017-04-30                          91.515724
# 2017-05-31                           0.000000
#
# [5 rows x 29 columns]

# %%
china.plot(figsize=(15, 9),kind='area',ylabel='M3m', title='LNG imports in China')
# Out:
# <Axes: title={'center': 'LNG imports in China'}, ylabel='M3m'>

# %%
col = china.columns

# %%
china['Total'] = china.sum(axis=1)

# %%
(china['Total']['2023-01':'2023-04'].sum()/china['Total']['2022-01':'2022-04'].sum()-1)*100
# Out:
# 2.4272591020925827

# %%
china.columns
# Out:
# Index(['Algeria', 'Angola', 'Australia', 'Belgium', 'Brunei Darussalam',
#        'Cameroon', 'China', 'Egypt', 'Equatorial Guinea', 'France', 'India',
#        'Indonesia', 'Japan', 'Malaysia', 'Netherlands', 'Nigeria', 'Norway',
#        'Oman', 'Papua New Guinea', 'Peru', 'Qatar', 'Russia', 'Singapore',
#        'South Korea', 'Spain', 'Trinidad & Tobago', 'United Arab Emirates',
#        'United Kingdom', 'United States of America', 'Total', 'Other'],
#       dtype='object', name='Origin_Berthcountry')

# %%
## Define an "Other" category
china['Other']= china.loc[:, ~china.columns.isin(['Total','Russia','Australia','United States of America','Qatar','Indonesia','Malaysia'])].sum(axis=1)

# %%
china_r = china[['Russia','Australia','Qatar','United States of America','Indonesia','Malaysia','Other']]

# %%
china_twh = china_r*10.3/1000

# %%
china_twh.plot(figsize=(15, 9),kind='area',ylabel='TWh', title='LNG imports in China')
# Out:
# <Axes: title={'center': 'LNG imports in China'}, ylabel='TWh'>

# %% [markdown]
# ## Single out Russia

# %%
## Here we get 
russia = df[df['Origin_Berthcountry'].isin(['Russia'])].reset_index()

# %%
russia.head()
# Out:
#    index Port_Country Origin_Berthcountry  2018-12-31 00:00:00  \
# 0      6    Argentina              Russia                  NaN
# 1     15      Belgium              Russia            -71595.45
# 2     24       Brazil              Russia                  NaN
# 3     31       Canada              Russia                  NaN
# 4     56        China              Russia           -123147.00
#
#    2018-11-30 00:00:00  2018-10-31 00:00:00  2018-09-30 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN            -142697.7            -71793.00
# 2                  NaN             -65317.5           -196782.75
# 3                  NaN                  NaN                  NaN
# 4           -580022.55             -61050.6                  NaN
#
#    2018-08-31 00:00:00  2018-07-31 00:00:00  2018-06-30 00:00:00  ...  \
# 0             -56829.6                  NaN                  NaN  ...
# 1             -71564.4                  NaN                  NaN  ...
# 2                  NaN                  NaN                  NaN  ...
# 3                  NaN            -69846.30                  NaN  ...
# 4                  NaN           -212571.45            -69163.65  ...
#
#    2021-06-30 00:00:00  2021-05-31 00:00:00  2021-04-30 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1             -8365.50           -300006.00            -147714.3
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4           -386602.65           -315743.85            -261470.7
#
#    2021-03-31 00:00:00  2021-02-28 00:00:00  2021-01-31 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1           -215248.05            -71794.80            -76062.15
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4           -317291.40           -195880.95           -499562.10
#
#    2023-04-30 00:00:00  2023-03-31 00:00:00  2023-02-28 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1            -320097.6           -408711.15            -367039.8
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4            -591606.9           -578358.90            -518009.4
#
#    2023-01-31 00:00:00
# 0                  NaN
# 1           -227736.45
# 2                  NaN
# 3                  NaN
# 4           -449018.55
#
# [5 rows x 79 columns]

# %%
cols = russia.iloc[:,1]

# %%
values = russia.iloc[:,3:]*converter

# %%
russia = pd.concat([cols,values], axis=1)

# %%
russia = russia.groupby(['Port_Country']).sum(numeric_only=True)

# %%
russia = russia.T

# %%
russia.index = pd.to_datetime(russia.index)
russia = russia.sort_index()

# %%
russia['EU28']= russia.loc[:, russia.columns.isin(['Belgium','Finland','France','Greece','Qatar','Italy','Lithuania','Netherlands','Sweden','United Kingdom'])].sum(axis=1)

# %%
russia['non_EU28'] = russia.loc[:, ~russia.columns.isin(['EU28'])].sum(axis=1)

# %%
russia_c = russia[['EU28','non_EU28']]

# %%
russia['EU28']['2023'].sum()/(russia['non_EU28']['2023'].sum()+russia['EU28']['2023'].sum())*100
# Out:
# 22.340107140086044

# %%
russia_c.plot(figsize=(15, 9),kind='area',ylabel='M3m', title='LNG exports from Russia')
# Out:
# <Axes: title={'center': 'LNG exports from Russia'}, ylabel='M3m'>
